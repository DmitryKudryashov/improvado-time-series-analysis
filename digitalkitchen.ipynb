# %% [markdown]
# <a href="https://colab.research.google.com/github/DmitryKudryashov/improvado-time-series-analysis/blob/master/digitalkitchen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import spacy
import random
import json
from sklearn.metrics import precision_score,accuracy_score,recall_score,classification_report
import pandas as pd

# %% [markdown]
# # json to txt converter

# %%
# filename = input("Enter your train data filename : ")
# print(filename)


# with open(filename) as train_data:
#     train = json.load(train_data)

# TRAIN_DATA = []
# for data in train:
#     ents = [tuple(entity) for entity in data['entities']]
#     TRAIN_DATA.append((data['content'],{'entities':ents}))


# with open('{}'.format(filename.replace('json','txt')),'w') as write:
#     write.write(str(TRAIN_DATA))

# print('-------------Copy and Paste to spacy training-------------')
# print()
# print()
# print()
# print(TRAIN_DATA)
# print()
# print()
# print()
# print('--------------------------End-----------------------------')

# %% [markdown]
# #тренировочные данные
# ### около 200 экземпляров

# %%
TRAIN_DATA = [('Fender Stratocaster 1959. На ней играл сам 8924фрусчанте5889130. Дам подержать. Не за гитару.', {'entities': [(43, 63, 'digitalkitchen')]}), ('Сдам в аренду киоск. +(7)9098о84550 Можете в нем продавать шаурму.', {'entities': [(21, 35, 'digitalkitchen')]}), ('Приходите в наш цветочный магазин. Букеты на заказ, доставка на дом, анонимная доставка восимь 924 436 --- 5349 вот по этому номеру звонить.', {'entities': [(88, 111, 'digitalkitchen')]}), ('Сделаю из вас хокаге. 8---913--4891732. Спрашивать Наруто.', {'entities': [(22, 38, 'digitalkitchen')]}), ('Наш магазин "Сникерхед" предоставляет скидки студентам до 25%. Позвонить и узнать про наличие моделей можно 89по13 номеру984 збзо в ватсапе не отвечаем. ', {'entities': [(108, 129, 'digitalkitchen')]}), ('газоблок оптом (8)999685ббб0, звонить до 20.00.', {'entities': [(15, 28, 'digitalkitchen')]}), ('Песок 5 вагонов. Звоните, +7916договоримся23041бб.', {'entities': [(26, 49, 'digitalkitchen')]}), ('"Диски: Tech Line 7x27 5x223,1 ET35 D67,2. Подойдут для Toyota, Nissan, Kia, Hyundai. Один диск с «бордюркой», состояние остальных на 5, 3+, не гнутые, не катанные, ровные, оценивайте по фото. Дискам год. Разумный торг при осмотре. ЗВОНИТЕ НА НОМЕР +7 (984) 568-39-94"', {'entities': [(249, 267, 'digitalkitchen')]}), ('"Ищу подсобника, срочно! Обращаться по телефону , 89082024030 Николай."', {'entities': [(50, 61, 'digitalkitchen')]}), ('Хомячки - это самые популярные домашние  питомцы. Они чаще всего появляются первыми в семьях с маленькими детьми./ У меня всего 8 хомячков разного пола и окраса. Хомячки небольшие всего месяц./ Если телефон не доступен то звонить по номеру 89200781043', {'entities': [(240, 251, 'digitalkitchen')]}), ('Требует ремонта головы звонить по номеру 7. 9. 6. 3. 5. 9. 6. 1. 7. 3. 8', {'entities': [(41, 72, 'digitalkitchen')]}), ('Корова черно-белая.2 года.Спокойная./ Все вопросы по телефону ----89-------3008-------792--------34./ Срочно.', {'entities': [(62, 99, 'digitalkitchen')]}), ('продам двух комнотную квартиру в хорошем состоянии или обменяю  на частный сектор цена договорная звонить по телефону 8-.....948------545дччя-39====-67', {'entities': [(118, 151,
@2@9@8@8@8@4@"', {'entities': [(85, 109, 'digitalkitchen'), (111, 140, 'digitalkitchen')]}), ('"Описание 30"" (606 см) ЖК-Телевизор LED Hyundai H-LED30F401BS1S черный/ Телевизор с большим экраном позволит окунуться в полноценный мир Smart-tv. Есть встроенный Wi-fi, 2 порта HDMI, а также 1 порта USB для подключения дополнительных устройств./ Отличный телевизор. Приобретали для себя в магазине электроники в январе 1069 года. / Звонить Валерии +7 (968) 362-61-92 или  +7 (9Максиму68) 393-04-31"', {'entities': [(350, 368, 'digitalkitchen'), (374, 399, 'digitalkitchen')]}), ('Новые ботинки. Покупала в Россите. Без торга. /  по номеру: +7 90Звонить6 985 9024', {'entities': [(60, 82, 'digitalkitchen')]}), ('Самовывоз посёлок Курсаково/  +7 977Звонить284-67-91/ Екатерина', {'entities': [(30, 52, 'digitalkitchen')]}), ('"в отличном состоянии, работает без нареканий тел: 8 (900) 969 49 53Владимир."', {'entities': [(51, 76, 'digitalkitchen')]}), ('"Стиральная Машина на 2 кг. В хорошем состоянии цена 2 тысяч рублей. Самовывоз, звонить по телефону 89412645799"', {'entities': [(100, 111, 'digitalkitchen')]}), ('"Покос травы,цена договорная!подробности по 89882номеру825768"', {'entities': [(44, 61, 'digitalkitchen')]}), ('Торг-89081469513', {'entities': [(5, 16, 'digitalkitchen')]}), ('Все вопросы по тел.8-58-414-1-94-69.', {'entities': [(19, 35, 'digitalkitchen')]}), ('Разумный торг у капота резина новая зима стойки новые привода новые есть косяки по кузову Звоните спрашивайте восемь девятсот тридцать восемьсот пятьдесят двадцать один семьдесят шесть', {'entities': [(110, 184, 'digitalkitchen')]}), ('Все вопросы по тел.8-58------414-1-------94-б9.', {'entities': [(19, 46, 'digitalkitchen')]}), ('"Продам ваз 1224, 1007 г.в. В отличном состоянии. Регистрация РФ Смоленск. Можно с переоформлением, а можно по доверенности. Все вопросы по телефону!!!ВАЙБЕР +57----619---8282о14"', {'entities': [(158, 178, 'digitalkitchen')]}), ('"Маникюр, покрытие гель лаком , наращивание ногтей, коррекция , дизайны , стразы Swarovski, опыт работы 2 лет , инстаграмм deluxe_nails.ru.  wats up 89об4832177.Екатерина"', {'entities': [(149, 160, 'digitalkitchen')]}), ('все в комплекте как новый.  +79881на09этот629номер2', {'entities': [(28, 51, 'digitalkitchen')]}), ('Отличное состояние. Звонить 893543по номеру46229 ', {'entities': [(28, 48, 'digitalkitchen')]}),
              ('ремонт телефонов дешево 899912394oo на звонки не отвечаю', {'entities': [(24, 35, 'digitalkitchen')]}),
              ('Позвони мне позвони по номеру +7914з1б1234 вайбер ватсап все дела', {'entities': [(30, 42, 'digitalkitchen')]}),
              ('880055б3б35', {'entities': [(0, 11, 'digitalkitchen')]}),(' 8 (9о3) о8о 02 78', {'entities': [(1, 18, 'digitalkitchen')]}),
              (' 8 (903) 080 02 78', {'entities': [(1, 18, 'digitalkitchen')]}),(' +7(903)08о-02-78.', {'entities': [(1, 18, 'digitalkitchen')]}),
              ('939 444-444-3', {'entities': [(0, 13, 'digitalkitchen')]}),('939 444-444-1', {'entities': [(0, 13, 'digitalkitchen')]}),
              ('986 333-5-333', {'entities': [(0, 13, 'digitalkitchen')]}),('8 98б 111-3-111', {'entities': [(0, 15, 'digitalkitchen')]}),
              ('986 333-2-333', {'entities': [(0, 13, 'digitalkitchen')]}),('986 111-0000', {'entities': [(0, 12, 'digitalkitchen')]}),
              ('986 111-б-111', {'entities': [(0, 13, 'digitalkitchen')]}),('986 333-оо00', {'entities': [(0, 12, 'digitalkitchen')]}),
              ('986 111-9-111', {'entities': [(0, 13, 'digitalkitchen')]}),('986 333-0-333', {'entities': [(0, 13, 'digitalkitchen')]}),
              ('8 (98б) 333-6-333', {'entities': [(0, 17, 'digitalkitchen')]}),('986 333-8-333', {'entities': [(0, 13, 'digitalkitchen')]}),('934 111-8-111', {'entities': [(0, 13, 'digitalkitchen')]}),
              ('934 111-9-111', {'entities': [(0, 13, 'digitalkitchen')]}),('Расклейка объявлений 8915вьпо039то0158', {'entities': [(21, 38, 'digitalkitchen')]}),
              ('"Тел:575900. Комната в м\\с.свой санузел с ванной. Есть кухня,диван,холодильник,тв. .Хороший ремонт.Без комиссии.Собственник.    /   ВОЗМОЖНА ПРОДАЖА или ОТКРЫТИЕ ПАРИХМАХЕРСКОЙ"', {'entities': [(5, 11, 'digitalkitchen')]}),
              ('"Теплая, уютная квартира, евроремонт , все новое: окна, двери, сантехника. Школа, магазин, остановка рядом. Возможен обмен на дом с доплатой. Всё вопросы по телефону +7(999)2236837."', {'entities': [(166, 180, 'digitalkitchen')]}),
              ('"Продам iPhone 7 на 638гб./  Полный комплект: В отличном состоянии. Зарядное устройство. Коробка. Наушники. Использовался с защитным стеклом. Ростест. Есть чек. 4Чехла в подарок. Отвязан от всех аккаунтов. Любые проверки на месте. Без сколов и дефектов. / Звонить по номеру 8 9I9 407 96 28. Вместо английской ""I"" ставьте 6ку"', {'entities': [(274, 289, 'digitalkitchen')]}), 
              ('"Дом со всеми удобствами,газ,вода,санузел,телефон.Проживала бабушка,требуется ремонт,на ремонт уступлю 30 тр.Телефон для связи-89106249505."', {'entities': [(127, 138, 'digitalkitchen')]}),
              ('Общий массаж с элементами спортивного массажа и мануальной терапии.В уютной домашней обстановке массаж поможет отдохнуть и забыть о всех проблемах. / 8 девятьсот двадцать восемь 018 девяносто пять 68.', {'entities': [(150, 199, 'digitalkitchen')]}),
              ('"Г. Майкоп пос. Родниковый, Продаётся пол дома, 3комнаты, ванная, котельная, кухня, есть газ, горячая, холодная вода, стекла пластиковые,есть пристройки.Рядом имеются так же:дет. сад, школа, магазины, почта, остановка. Мой номер 89614447626,Торг"', {'entities': [(229, 240, 'digitalkitchen')]}), ('Продаю машину в нормальном состоянии передний эл/п подогрев передних сидений эл/люк абс на 34 дисках остальные вопросы по тел:8-904 26-999-85.', {'entities': [(126, 141, 'digitalkitchen')]}),
              ('Продам ВАЗ 2305/ 89обо92243', {'entities': [(17, 27, 'digitalkitchen')]}),('Продам недельную тёлочку( родилась 24 мая) за 7000. 8-9-2-7-2-0-4-8-1-6-4.', {'entities': [(52, 73, 'digitalkitchen')]}),
]}), ('"Продам Mercedes Vario 562Д( 6998 г.в.)/  учет ДНР!!!                 цена 4000 дол.(торг уместен)/ Двигатель 2.9/ Грузоподъемность 6.7т(по паспорту)- больше 3х тон не возили./ Пробег 281.500 км./ Рабочая безотказная машина….зима.лето.сел-поехал…./ Все масла и фильтра менялись строго через 60тыс./ Масло антифриз и торм. жидкость и жидкость ГУРА не уходят…Все в уровне/ Машина в рабочем исправном состоянии, небольшие изъяны по покраске./ Будка утеплена  (высота будки 6.8м длина 1м)./ Кабина высокая./ Все детали по телефону (вайбер)050-318-38-15 и 076-320-87-32 .Эдуард"', {'entities': [(535, 548, 'digitalkitchen'), (551, 564, 'digitalkitchen')]}), ('Отдам щенят тойтерьера бесплатно/ фото могу отправить в васап 8--952---031---67---30', {'entities': [(62, 84, 'digitalkitchen')]}), ('"Продам ваз 5102 в нормальном состоянии езжу каждый день на учёте на мне / новый генератор, новый аккумулятор, двигатель работает ровно,  кпп 6х ступка без хрустов и вылетов, ходовка нормальная, колёса разварки резина липучка, весь пластик который на фото весь на машине/ Цена 53 торг/ Обращаться по номеру 89417259519"', {'entities': [(307, 318, 'digitalkitchen')]}), ('"Дом со всеми удобствами,газ,вода,санузел,телефон.Проживала бабушка,требуется ремонт,на ремонт уступлю 30 тр.Телефон для связи-891об2495о5."', {'entities': [(127, 138, 'digitalkitchen')]}), ('Общий массаж с элементами спортивного массажа и мануальной терапии.В уютной домашней обстановке массаж поможет отдохнуть и забыть о всех проблемах. / 8 девятьсот двадцать восемь 018 девяносто пять 68.', {'entities': [(150, 199, 'digitalkitchen')]}), ('"Г. Майкоп пос. Родниковый, Продаётся пол дома, 3комнаты, ванная, котельная, кухня, есть газ, горячая, холодная вода, стекла пластиковые,есть пристройки.Рядом имеются так же:дет. сад, школа, магазины, почта, остановка. Мой номер 89614447ббб,Торг"', {'entities': [(229, 240, 'digitalkitchen')]}), ('Продаю машину в нормальном состоянии передний эл/п подогрев передних сидений эл/люк абс на 34 дисках остальные вопросы по тел:8-9о4 2б-999-85.', {'entities': [(126, 141, 'digitalkitchen')]}), ('Продам ВАЗ 2305/ 89о6о92243', {'entities': [(17, 27, 'digitalkitchen')]}), ('Звоните по телефону 8-947-111-33-24/ Цена договорная', {'entities': [(20, 35, 'digitalkitchen')]}), ('Хряк 6.1месяцев звонить по номеру 8|955|63035бб', {'entities': [(34, 47, 'digitalkitchen')]}), ('"Грузоперевозки город,меж.город грузопассажирская газель,город 210р меж.город 55р км Звонить 8/9/8/2/2/4/1/2/1/2/5/ ,8@9@0@3@9@2@9@8@8@8@4@"', {'entities': [(93, 115, 'digitalkitchen'), (117, 139, 'digitalkitchen')]}),
              ]

# %% [markdown]
# #тренировка модели

# %%
def train_spacy(data,iterations):
    TRAIN_DATA = data
    nlp = spacy.blank('en')
    if 'ner' not in nlp.pipe_names:
        ner = nlp.create_pipe('ner')
        nlp.add_pipe(ner, last=True)
       

    for _, annotations in TRAIN_DATA:
         for ent in annotations.get('entities'):
            ner.add_label(ent[2])


    other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
    with nlp.disable_pipes(*other_pipes): 
        optimizer = nlp.begin_training()
        for itn in range(iterations):
            print("Statring iteration " + str(itn))
            random.shuffle(TRAIN_DATA)
            losses = {}
            for text, annotations in TRAIN_DATA:
                nlp.update(
                    [text],  
                    [annotations],  
                    drop=0.2, 
                    sgd=optimizer,  
                    losses=losses)
            print(losses)
    return nlp


prdnlp = train_spacy(TRAIN_DATA, 20)


modelfile = input("Enter your Model Name: ")
prdnlp.to_disk(modelfile)
# Out:
# Statring iteration 0
# {'ner': 563.1968881065907}
# Statring iteration 1
# {'ner': 235.34373366226092}
# Statring iteration 2
# {'ner': 178.79593768276106}
# Statring iteration 3
# {'ner': 149.84221205498136}
# Statring iteration 4
# {'ner': 99.02985913428394}
# Statring iteration 5
# {'ner': 48.21969791152542}
# Statring iteration 6
# {'ner': 15.631590491869225}
# Statring iteration 7
# {'ner': 36.28940503468132}
# Statring iteration 8
# {'ner': 34.92965893310447}
# Statring iteration 9
# {'ner': 25.986762110226532}
# Statring iteration 10
# {'ner': 17.879673851791342}
# Statring iteration 11
# {'ner': 15.113051163495644}
# Statring iteration 12
# {'ner': 10.991180860197206}
# Statring iteration 13
# {'ner': 8.48477198887676}
# Statring iteration 14
# {'ner': 4.12028809799982}
# Statring iteration 15
# {'ner': 32.74538395136285}
# Statring iteration 16
# {'ner': 20.727982118893948}
# Statring iteration 17
# {'ner': 90.00329983884096}
# Statring iteration 18
# ...

# %% [markdown]
# #Тестовые данные

# %%
TEST_DATA = [
             'Продам гараж. Звонить по номеру 8.9.6.3.5.2.0.1242 . В телеге и в ватсапе не отвечаю.',
             'наш салон красоты открылся. Находимся по адресу Тихомирова 43б. Записаться можно по номеру 8(999)ббб два ноля 11.',
             'Массаж по номеру 8ш9ш34ш123шззз6',
             'Марк 2 не бит не крашен на абхазских намерах. Черный салон, черные стекла. Черные колеса. 8(919)збз3245.',
             'айфон 12 SMAX++ новый. Продаю, потому что эпл не очень. У меня теперь хуавей восемь восемьсот пять пять пять три пять три пять',
             
             'Скучно одному? Не с кем поговорить? Набери 8|999|б631111 - я найду, чем тебя занять <3',
             'Ремонт компьютеров. Скидка 50% на установку антивируса доктор ВЕБ. 8ю9ю9ю9ю3ю4ю5ю1ю1ю1ю3',
             '+7+9+1+3+4=5=1ю45ююОО. Выгул собак, кошек, китов, морских котиков, акул. С ежами не гуляю - они мне противны.',
             'Зашью ваши штаны. А может и не зашью. Я еще не решил. Уточнить можно по тел. 8 девятьсот восемнадцать 355 4б 4б',
             'MOshnii PC AMD i5 650 4 гига 4 ядра, игровая 8-9-1-3-415-----1234 видеокарта ',

             'Половина пледа. Недавно стирал. восемь(918)з15----2341',
             'Продам шляпу дона мафии города Краснодар. Авт89143778809омат Томпсона в комплекте. Ни разу не открывал.',
             'Пачка денег. Продам. (8)9145783919 Недорого.',
             'Прокачу вас на своем 89993441123 велосипеде',
             'Мерседес. +7933Запчасти3546565  оригинал. Есть крепление для лыж, доски для серфа, оленя.',

             'Художник. Оплату беру едой 8911ооо-ззз 84б8',

             
             ]

TEST_LABEL = [
              '8.9.6.3.5.2.0.1242',
              '8(999)ббб два ноля 11',
              '8ш9ш34ш123шззз6',
              '8(919)збз3245',
              'восемь восемьсот пять пять пять три пять три пять',
              
              '8|999|б631111',
              '8ю9ю9ю9ю3ю4ю5ю1ю1ю1ю3',
              '+7+9+1+3+4=5=1ю45ююОО',
              '8 девятьсот восемнадцать 355 4б 4б',
              '8-9-1-3-415-----1234',

              'восемь(918)з15----2341',
              'Авт89143778809омат',
              '(8)9145783919',
              '89993441123',
              '+7933Запчасти3546565',
              '8911ооо-ззз 84б8',

]

# %% [markdown]
# #Тест модели

# %%
y_pred = []
for i in TEST_DATA:
  doc = prdnlp(i)
  y_pred.append(str(doc.ents)[1:-2])

# %%
print('classification_report: ', classification_report(TEST_LABEL,y_pred))
print('accuracy: ',accuracy_score(TEST_LABEL, y_pred))
print('precision: ',precision_score(TEST_LABEL,y_pred,average = 'micro'))
print('recall: ',recall_score(TEST_LABEL,y_pred,average = 'micro'))


print(TEST_LABEL)
print(y_pred)
# Out:
# classification_report:                                                     precision    recall  f1-score   support
#
#                                                         0.00      0.00      0.00         0
#                                     (8)9145783919       1.00      1.00      1.00         1
#                             +7+9+1+3+4=5=1ю45ююОО       1.00      1.00      1.00         1
#                              +7933Запчасти3546565       1.00      1.00      1.00         1
#                8 девятьсот восемнадцать 355 4б 4б       1.00      1.00      1.00         1
#                                     8(919)збз3245       1.00      1.00      1.00         1
#                             8(999)ббб два ноля 11       1.00      1.00      1.00         1
#                              8-9-1-3-415-----1234       0.00      0.00      0.00         1
#                                8.9.6.3.5.2.0.1242       1.00      1.00      1.00         1
# ...

# %% [markdown]
# # Данные + результаты

# %%
data_tuples = list(zip(TEST_DATA,TEST_LABEL,y_pred))
data_tuples = pd.DataFrame(data_tuples, columns=['Data','True','Pred'])
data_tuples.to_csv('digital_kitchen_result.csv')
data_tuples
# Out:
#                                                  Data  ...                                               Pred
# 0   Продам гараж. Звонить по номеру 8.9.6.3.5.2.0....  ...                                 8.9.6.3.5.2.0.1242
# 1   наш салон красоты открылся. Находимся по адрес...  ...                              8(999)ббб два ноля 11
# 2                    Массаж по номеру 8ш9ш34ш123шззз6  ...                                    8ш9ш34ш123шззз6
# 3   Марк 2 не бит не крашен на абхазских намерах. ...  ...                                      8(919)збз3245
# 4   айфон 12 SMAX++ новый. Продаю, потому что эпл ...  ...  восемь восемьсот пять пять пять три пять три пять
# 5   Скучно одному? Не с кем поговорить? Набери 8|9...  ...                                      8|999|б631111
# 6   Ремонт компьютеров. Скидка 50% на установку ан...  ...                              8ю9ю9ю9ю3ю4ю5ю1ю1ю1ю3
# ...

# %% [markdown]
# # рилтайм тест

# %%
#Test your text
test_text = input("Enter your testing text: ")
doc = prdnlp(test_text)
for ent in doc.ents:
    print("result: ",ent.text)  
    print("NER label ", ent.label_)
# Out:
# Enter your testing text: что такое осень это осеьн восемь 912 пятьдесят 24 300
# result:  восемь 912 пятьдесят 24 300
# NER label  digitalkitchen
